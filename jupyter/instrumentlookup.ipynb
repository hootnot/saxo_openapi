# %% [markdown]
# # Instrument Lookup
#
# [index](./index.ipynb) |
# [accounts](./accounts.ipynb) |
# [balances](./balances.ipynb) |
# [trading](./trading.ipynb)

# %%
from saxo_openapi import API
from saxo_openapi.exceptions import OpenAPIError
from saxo_openapi.contrib.session import account_info
import saxo_openapi.endpoints.referencedata as rd
import saxo_openapi.definitions.orders as OD
import json
import exampleauth

# %%
token = exampleauth.read_token()
client = API(access_token=token)
ai = account_info(client)

# %% [markdown]
# ## Lookup all there is for EURUSD

# %%
r = rd.instruments.Instruments(params = {'AccountKey': ai.AccountKey,
                                         'KeyWords': 'EURUSD'})
print(json.dumps(client.request(r), indent=2))
# Out:
# {
#   "Data": [
#     {
#       "AssetType": "FxSpot",
#       "CurrencyCode": "USD",
#       "Description": "Euro/US Dollar",
#       "ExchangeId": "SBFX",
#       "GroupId": 28993,
#       "Identifier": 21,
#       "IsKeywordMatch": true,
#       "SummaryType": "Instrument",
#       "Symbol": "EURUSD",
#       "TradableAs": [
#         "FxSpot",
#         "FxForwards",
#         "FxVanillaOption",
#         "FxKnockInOption",
#         "FxKnockOutOption",
#         "FxOneTouchOption",
#         "FxNoTouchOption"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "USD",
#       "Description": "EURUSD - Jun 2019",
#       "ExchangeId": "CME",
#       "GroupId": 28379,
#       "Identifier": 9865225,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 9865225,
#       "SummaryType": "Instrument",
#       "Symbol": "ECM9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "USD",
#       "Description": "EURUSD - Sep 2019",
#       "ExchangeId": "CME",
#       "GroupId": 28379,
#       "Identifier": 10795354,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 9865225,
#       "SummaryType": "Instrument",
#       "Symbol": "ECU9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "USD",
#       "Description": "EURUSD - Dec 2019",
#       "ExchangeId": "CME",
#       "GroupId": 28379,
#       "Identifier": 11495475,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 9865225,
#       "SummaryType": "Instrument",
#       "Symbol": "ECZ9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "USD",
#       "Description": "E-micro EURUSD - Jun 2019",
#       "ExchangeId": "CME",
#       "GroupId": 28554,
#       "Identifier": 11495645,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 11495645,
#       "SummaryType": "Instrument",
#       "Symbol": "M6EM9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "USD",
#       "Description": "E-mini EURUSD - Jun 2019",
#       "ExchangeId": "CME",
#       "GroupId": 28359,
#       "Identifier": 11495466,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 11495466,
#       "SummaryType": "Instrument",
#       "Symbol": "E7M9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "EUR",
#       "Description": "Rapeseed Euro - May 2019",
#       "ExchangeId": "EUR_PAR1",
#       "GroupId": 28542,
#       "Identifier": 8647018,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 8647018,
#       "SummaryType": "Instrument",
#       "Symbol": "ECOK9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "EUR",
#       "Description": "Rapeseed Euro - Aug 2019",
#       "ExchangeId": "EUR_PAR1",
#       "GroupId": 28542,
#       "Identifier": 9450677,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 8647018,
#       "SummaryType": "Instrument",
#       "Symbol": "ECOQ9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "EUR",
#       "Description": "Rapeseed Euro - Nov 2019",
#       "ExchangeId": "EUR_PAR1",
#       "GroupId": 28542,
#       "Identifier": 10077685,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 8647018,
#       "SummaryType": "Instrument",
#       "Symbol": "ECOX9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "EUR",
#       "Description": "Rapeseed Euro - Feb 2020",
#       "ExchangeId": "EUR_PAR1",
#       "GroupId": 28542,
#       "Identifier": 11050663,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 8647018,
#       "SummaryType": "Instrument",
#       "Symbol": "ECOG0",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "EUR",
#       "Description": "Rapeseed Euro - May 2020",
#       "ExchangeId": "EUR_PAR1",
#       "GroupId": 28542,
#       "Identifier": 11722153,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 8647018,
#       "SummaryType": "Instrument",
#       "Symbol": "ECOK0",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "ContractFutures",
#       "CurrencyCode": "CAD",
#       "Description": "EURCAD - Jun 2019",
#       "ExchangeId": "CME",
#       "GroupId": 28376,
#       "Identifier": 11495472,
#       "IsKeywordMatch": true,
#       "PrimaryListing": 11495472,
#       "SummaryType": "Instrument",
#       "Symbol": "ECDM9",
#       "TradableAs": [
#         "ContractFutures"
#       ]
#     },
#     {
#       "AssetType": "FuturesOption",
#       "CanParticipateInMultiLegOrder": false,
#       "Description": "EURUSD Weekly (2) - 2pm fix",
#       "ExchangeId": "CME",
#       "GroupId": 28379,
#       "Identifier": 1281,
#       "SummaryType": "ContractOptionRoot",
#       "Symbol": "2EU:xcme"
#     },
#     {
#       "AssetType": "FuturesOption",
#       "CanParticipateInMultiLegOrder": false,
#       "Description": "EURUSD Weekly (3) - 2pm fix",
#       "ExchangeId": "CME",
#       "GroupId": 28379,
#       "Identifier": 1282,
#       "SummaryType": "ContractOptionRoot",
#       "Symbol": "3EU:xcme"
#     },
#     {
#       "AssetType": "FuturesOption",
#       "CanParticipateInMultiLegOrder": false,
#       "Description": "EURUSD Weekly (4) - 2pm fix",
#       "ExchangeId": "CME",
#       "GroupId": 28379,
#       "Identifier": 1283,
#       "SummaryType": "ContractOptionRoot",
#       "Symbol": "4EU:xcme"
#     },
#     {
#       "AssetType": "FuturesOption",
#       "CanParticipateInMultiLegOrder": false,
#       "Description": "EURUSD - 2pm fix",
#       "ExchangeId": "CME",
#       "GroupId": 28379,
#       "Identifier": 1279,
#       "SummaryType": "ContractOptionRoot",
#       "Symbol": "EUU:xcme"
#     }
#   ]
# }

# %% [markdown]
# ## Narrow that query ...

# %%
r = rd.instruments.Instruments(params = {'AccountKey': ai.AccountKey,
                                         'KeyWords': 'EURUSD',
                                         'AssetTypes': 'FxSpot'})
print(json.dumps(client.request(r), indent=2))
# Out:
# {
#   "Data": [
#     {
#       "AssetType": "FxSpot",
#       "CurrencyCode": "USD",
#       "Description": "Euro/US Dollar",
#       "ExchangeId": "SBFX",
#       "GroupId": 28993,
#       "Identifier": 21,
#       "IsKeywordMatch": true,
#       "SummaryType": "Instrument",
#       "Symbol": "EURUSD",
#       "TradableAs": [
#         "FxSpot",
#         "FxForwards",
#         "FxVanillaOption",
#         "FxKnockInOption",
#         "FxKnockOutOption",
#         "FxOneTouchOption",
#         "FxNoTouchOption"
#       ]
#     }
#   ]
# }

# %% [markdown]
# So, to trade EURUSD FxSpot use:
#
#   + Uic = 21
#   + AssetType = FxSpot
#
# ## Lookup some stock
#
# ... for instance Royal Dutch Shell traded at Amsterdam

# %%
r = rd.instruments.Instruments(params = {'AccountKey': ai.AccountKey,
                                         'KeyWords': 'Shell',
                                         'AssetTypes': 'Stock',
                                         'ExchangeIds': 'AMS'})
print(json.dumps(client.request(r), indent=2))
# Out:
# {
#   "Data": [
#     {
#       "AssetType": "Stock",
#       "CurrencyCode": "EUR",
#       "Description": "Royal Dutch Shell Plc B",
#       "ExchangeId": "AMS",
#       "GroupId": 1833,
#       "Identifier": 46278,
#       "IssuerCountry": "GB",
#       "PrimaryListing": 16348,
#       "SummaryType": "Instrument",
#       "Symbol": "RDSB:xams",
#       "TradableAs": [
#         "Stock"
#       ]
#     },
#     {
#       "AssetType": "Stock",
#       "CurrencyCode": "EUR",
#       "Description": "Royal Dutch Shell Plc A",
#       "ExchangeId": "AMS",
#       "GroupId": 1833,
#       "Identifier": 16350,
#       "IssuerCountry": "GB",
#       "PrimaryListing": 16348,
#       "SummaryType": "Instrument",
#       "Symbol": "RDSa:xams",
#       "TradableAs": [
#         "Stock"
#       ]
#     }
#   ]
# }

# %% [markdown]
# The *Identifier* is the *Uic* to use when placing an order.
#
# ## What about options ?

# %%
r = rd.instruments.Instruments(params = {'AccountKey': ai.AccountKey,
                                         'KeyWords': 'Shell',
                                         'AssetTypes': 'StockOption'})
print(json.dumps(client.request(r), indent=2))
# Out:
# {
#   "Data": [
#     {
#       "AssetType": "StockOption",
#       "CanParticipateInMultiLegOrder": false,
#       "Description": "Royal Dutch Shell Plc B",
#       "ExchangeId": "ICE_LIF",
#       "GroupId": 1833,
#       "Identifier": 706,
#       "SummaryType": "ContractOptionRoot",
#       "Symbol": "RDSB:xlif"
#     },
#     {
#       "AssetType": "StockOption",
#       "CanParticipateInMultiLegOrder": false,
#       "Description": "Royal Dutch Shell Plc A",
#       "ExchangeId": "ICE_LIF",
#       "GroupId": 1833,
#       "Identifier": 718,
#       "SummaryType": "ContractOptionRoot",
#       "Symbol": "SHA:xlif"
#     },
#     {
#       "AssetType": "StockOption",
#       "CanParticipateInMultiLegOrder": false,
#       "Description": "Royal Dutch Shell Plc A",
#       "ExchangeId": "EUR_AMS2",
#       "GroupId": 1833,
#       "Identifier": 231,
#       "SummaryType": "ContractOptionRoot",
#       "Symbol": "RDSA:xams"
#     }
#   ]
# }

# %% [markdown]
# So, for Royal Ducth stockoptions traded at Amsterdam that would be *optionroot* = 231
#
# ### All options for Royal Dutch ...

# %%
OptionRootId = 231
r = rd.instruments.ContractoptionSpaces(OptionRootId=OptionRootId)
client.request(r)
print(json.dumps(r.response, indent=4))
# Out:
# {
#     "AmountDecimals": 0,
#     "AssetType": "StockOption",
#     "CanParticipateInMultiLegOrder": false,
#     "ContractSize": 100.0,
#     "CurrencyCode": "EUR",
#     "DefaultAmount": 1.0,
#     "DefaultExpiry": "2019-04-18T00:00:00Z",
#     "DefaultOption": {
#         "PutCall": "Call",
#         "StrikePrice": 27.0,
#         "Uic": 11897720,
#         "UnderlyingUic": 16350
#     },
#     "Description": "Royal Dutch Shell Plc A",
#     "Exchange": {
#         "CountryCode": "NL",
#         "ExchangeId": "EUR_AMS2",
#         "Name": "Euronext Equity & Index Derivatives - AMS"
#     },
#     "ExerciseStyle": "American",
#     "Format": {
#         "Decimals": 2,
#         "OrderDecimals": 2,
#         "StrikeDecimals": 3
#     },
#     "GroupId": 0,
#     "IncrementSize": 1.0,
#     "IsTradable": true,
#     "LotSize": 1.0,
#     "LotSizeType": "OddLotsNotAllowed",
#     "OptionRootId": 231,
#     "OptionSpace": [
#         {
#             "DisplayDaysToExpiry": 246,
#             "DisplayExpiry": "2019-12-01",
#             "Expiry": "2019-12-20",
#             "LastTradeDate": "2019-12-20T16:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 1426552,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 1426558,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 50.0,
#                     "Uic": 1485417,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 20.0,
#                     "Uic": 1394067,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 50.0,
#                     "Uic": 1485422,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 25.0,
#                     "Uic": 1394068,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 1394069,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 1394070,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 40.0,
#                     "Uic": 1394071,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 20.0,
#                     "Uic": 1394073,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 25.0,
#                     "Uic": 1394074,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 1394075,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 1394076,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 40.0,
#                     "Uic": 1394077,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 35.0,
#                     "Uic": 1719716,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 35.0,
#                     "Uic": 1719720,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 1869509,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 1869512,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 15.0,
#                     "Uic": 2235099,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 2235100,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 15.0,
#                     "Uic": 2235135,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 2235136,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 21.0,
#                     "Uic": 2355276,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 21.0,
#                     "Uic": 2355279,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 23.0,
#                     "Uic": 2330943,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 23.0,
#                     "Uic": 2330945,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 10.0,
#                     "Uic": 2600340,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 10.0,
#                     "Uic": 2600346,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 17.0,
#                     "Uic": 2522780,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 19.0,
#                     "Uic": 2522781,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 19.0,
#                     "Uic": 2522790,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 17.0,
#                     "Uic": 2522791,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 14.0,
#                     "Uic": 3044557,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 18.0,
#                     "Uic": 3044558,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 14.0,
#                     "Uic": 3044563,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 18.0,
#                     "Uic": 3044564,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 12.0,
#                     "Uic": 3270598,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 12.0,
#                     "Uic": 3270601,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 16.0,
#                     "Uic": 3344083,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 16.0,
#                     "Uic": 3344085,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 10249514,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 10249515,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.0,
#                     "Uic": 11715890,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 27.0,
#                     "Uic": 11715891,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 29.0,
#                     "Uic": 11773641,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 29.0,
#                     "Uic": 11773642,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         },
#         {
#             "DisplayDaysToExpiry": 612,
#             "DisplayExpiry": "2020-12-01",
#             "Expiry": "2020-12-18",
#             "LastTradeDate": "2020-12-18T16:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 10.0,
#                     "Uic": 3109447,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 15.0,
#                     "Uic": 3109448,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 20.0,
#                     "Uic": 3109449,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 25.0,
#                     "Uic": 3109450,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 3109451,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 10.0,
#                     "Uic": 3109456,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 15.0,
#                     "Uic": 3109457,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 20.0,
#                     "Uic": 3109458,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 25.0,
#                     "Uic": 3109459,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 3109460,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 18.0,
#                     "Uic": 3266271,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 18.0,
#                     "Uic": 3266279,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 3114842,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 3114844,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 12.0,
#                     "Uic": 3270599,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 12.0,
#                     "Uic": 3270602,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 16.0,
#                     "Uic": 3344084,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 16.0,
#                     "Uic": 3344086,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 40.0,
#                     "Uic": 3675842,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 50.0,
#                     "Uic": 3675843,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 35.0,
#                     "Uic": 3675838,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 40.0,
#                     "Uic": 3675839,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 50.0,
#                     "Uic": 3675840,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 35.0,
#                     "Uic": 3675841,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 4004044,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 4004045,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 4533017,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 4533019,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 5641048,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 5641050,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 21.0,
#                     "Uic": 8293640,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 23.0,
#                     "Uic": 8293641,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 21.0,
#                     "Uic": 8293649,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 23.0,
#                     "Uic": 8293650,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 10420482,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 10420483,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         },
#         {
#             "DisplayDaysToExpiry": 977,
#             "DisplayExpiry": "2021-12-01",
#             "Expiry": "2021-12-17",
#             "LastTradeDate": "2021-12-17T16:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 15.0,
#                     "Uic": 5778697,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 15.0,
#                     "Uic": 5778698,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 5777866,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 20.0,
#                     "Uic": 5777867,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 40.0,
#                     "Uic": 5777868,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 5777869,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 5777872,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 20.0,
#                     "Uic": 5777873,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 5777874,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 40.0,
#                     "Uic": 5777875,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 5792731,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 5792732,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 50.0,
#                     "Uic": 5887848,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 50.0,
#                     "Uic": 5887849,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 25.0,
#                     "Uic": 5925153,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 25.0,
#                     "Uic": 5925154,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 16.0,
#                     "Uic": 6215755,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 18.0,
#                     "Uic": 6215756,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 16.0,
#                     "Uic": 6215757,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 18.0,
#                     "Uic": 6215758,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 23.0,
#                     "Uic": 6899359,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 23.0,
#                     "Uic": 6899360,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 6665073,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 6665075,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 35.0,
#                     "Uic": 7818754,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 35.0,
#                     "Uic": 7818755,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 8082591,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 8082593,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 8293652,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 21.0,
#                     "Uic": 8293646,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 8293647,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 21.0,
#                     "Uic": 8293651,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         },
#         {
#             "DisplayDaysToExpiry": 63,
#             "DisplayExpiry": "2019-06-01",
#             "Expiry": "2019-06-21",
#             "LastTradeDate": "2019-06-21T15:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 20.0,
#                     "Uic": 7212832,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 7212833,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 7212834,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 7212837,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 7212838,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 7212839,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 7212840,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 20.0,
#                     "Uic": 7212842,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 7212844,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 7212845,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 18.0,
#                     "Uic": 7565261,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 18.0,
#                     "Uic": 7565264,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 21.0,
#                     "Uic": 7592975,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 21.0,
#                     "Uic": 7592978,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 15.0,
#                     "Uic": 7712981,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 15.0,
#                     "Uic": 7712982,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 7921747,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 7921749,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 40.0,
#                     "Uic": 8198044,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 40.0,
#                     "Uic": 8198045,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 23.0,
#                     "Uic": 8172435,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 23.0,
#                     "Uic": 8172436,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 35.0,
#                     "Uic": 8740841,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 35.0,
#                     "Uic": 8740842,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 9667892,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 9667902,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 45.0,
#                     "Uic": 9955296,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 29.0,
#                     "Uic": 9955297,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 45.0,
#                     "Uic": 9955302,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 29.0,
#                     "Uic": 9955306,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 27.0,
#                     "Uic": 10408534,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.0,
#                     "Uic": 10408535,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 25.0,
#                     "Uic": 10785468,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 25.0,
#                     "Uic": 10785472,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.5,
#                     "Uic": 13292074,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.5,
#                     "Uic": 13292075,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 27.5,
#                     "Uic": 13339749,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.5,
#                     "Uic": 13339756,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 34.0,
#                     "Uic": 13347241,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 34.0,
#                     "Uic": 13347231,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         },
#         {
#             "DisplayDaysToExpiry": 1342,
#             "DisplayExpiry": "2022-12-01",
#             "Expiry": "2022-12-16",
#             "LastTradeDate": "2022-12-16T16:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 8546977,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 25.0,
#                     "Uic": 8546980,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 20.0,
#                     "Uic": 8546982,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 40.0,
#                     "Uic": 8546983,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 20.0,
#                     "Uic": 8546986,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 8546987,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 25.0,
#                     "Uic": 8546988,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 40.0,
#                     "Uic": 8546991,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 8740845,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 50.0,
#                     "Uic": 8740847,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 8740848,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 50.0,
#                     "Uic": 8740850,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 8933563,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 8933571,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 15.0,
#                     "Uic": 9240171,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 18.0,
#                     "Uic": 9240173,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 9272583,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 9272584,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 15.0,
#                     "Uic": 9240169,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 18.0,
#                     "Uic": 9240170,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 10420487,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 10420484,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 35.0,
#                     "Uic": 10425694,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 35.0,
#                     "Uic": 10425696,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 10425700,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 10425704,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 23.0,
#                     "Uic": 11153676,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 23.0,
#                     "Uic": 11153685,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 21.0,
#                     "Uic": 11307211,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 21.0,
#                     "Uic": 11307212,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 27.0,
#                     "Uic": 11462187,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.0,
#                     "Uic": 11462188,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         },
#         {
#             "DisplayDaysToExpiry": 429,
#             "DisplayExpiry": "2020-06-01",
#             "Expiry": "2020-06-19",
#             "LastTradeDate": "2020-06-19T16:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 9955309,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 35.0,
#                     "Uic": 9955310,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 9955311,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 25.0,
#                     "Uic": 9955298,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 9955299,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 9955300,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 35.0,
#                     "Uic": 9955301,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 40.0,
#                     "Uic": 9955303,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 40.0,
#                     "Uic": 9955307,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 25.0,
#                     "Uic": 9955308,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 9974026,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 9974027,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 10426143,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 10426144,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 10426141,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 10426142,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 23.0,
#                     "Uic": 11153680,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 23.0,
#                     "Uic": 11153681,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 20.0,
#                     "Uic": 11169983,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 20.0,
#                     "Uic": 11169986,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 18.0,
#                     "Uic": 11307206,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 18.0,
#                     "Uic": 11307213,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 13342454,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 13342460,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         },
#         {
#             "DisplayDaysToExpiry": 155,
#             "DisplayExpiry": "2019-09-01",
#             "Expiry": "2019-09-20",
#             "LastTradeDate": "2019-09-20T15:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 10818177,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 10818182,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 40.0,
#                     "Uic": 10818185,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 35.0,
#                     "Uic": 10818186,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 45.0,
#                     "Uic": 10818187,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 29.0,
#                     "Uic": 10818188,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 10818189,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 10818190,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 10818191,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 10818192,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 10818193,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 10818194,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 45.0,
#                     "Uic": 10818198,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 40.0,
#                     "Uic": 10818203,
#                     "UnderlyingUic": 16350
#                 },
# ...
#                     "StrikePrice": 25.0,
#                     "Uic": 11897721,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 11897722,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 11897723,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 11897724,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 11897725,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 27.5,
#                     "Uic": 11897728,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 29.0,
#                     "Uic": 11897729,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.5,
#                     "Uic": 11897730,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.0,
#                     "Uic": 11897731,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.5,
#                     "Uic": 11897732,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 11897733,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 11897734,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 29.0,
#                     "Uic": 11897735,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 23.0,
#                     "Uic": 11900544,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 25.5,
#                     "Uic": 11903077,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 25.5,
#                     "Uic": 11903078,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 23.0,
#                     "Uic": 11900558,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 11949924,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 11949922,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.5,
#                     "Uic": 12007474,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.5,
#                     "Uic": 12007478,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 12003078,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 12003081,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 29.5,
#                     "Uic": 13347228,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 29.5,
#                     "Uic": 13347229,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         },
#         {
#             "DisplayDaysToExpiry": 32,
#             "DisplayExpiry": "2019-05-01",
#             "Expiry": "2019-05-17",
#             "LastTradeDate": "2019-05-17T15:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 12125561,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 25.0,
#                     "Uic": 12125562,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 12125563,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 27.5,
#                     "Uic": 12125564,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 12125565,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 12125566,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 29.0,
#                     "Uic": 12125567,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 12125568,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 27.0,
#                     "Uic": 12125569,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 12125570,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 25.0,
#                     "Uic": 12125571,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 12125572,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.0,
#                     "Uic": 12125573,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.5,
#                     "Uic": 12125574,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 12125575,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 29.0,
#                     "Uic": 12125576,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 12125577,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 12125578,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.5,
#                     "Uic": 12216406,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.5,
#                     "Uic": 12216411,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.5,
#                     "Uic": 13267382,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.5,
#                     "Uic": 13267386,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 34.0,
#                     "Uic": 13347222,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 34.0,
#                     "Uic": 13347223,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         },
#         {
#             "DisplayDaysToExpiry": 337,
#             "DisplayExpiry": "2020-03-01",
#             "Expiry": "2020-03-20",
#             "LastTradeDate": "2020-03-20T16:30:00.000000Z",
#             "SpecificOptions": [
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 26.0,
#                     "Uic": 13339744,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 24.0,
#                     "Uic": 13339745,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 24.0,
#                     "Uic": 13339750,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 28.0,
#                     "Uic": 13339751,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 29.0,
#                     "Uic": 13339752,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 22.0,
#                     "Uic": 13339753,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 28.0,
#                     "Uic": 13339754,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 40.0,
#                     "Uic": 13339755,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 27.0,
#                     "Uic": 13339757,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 29.0,
#                     "Uic": 13339758,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 35.0,
#                     "Uic": 13339759,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 22.0,
#                     "Uic": 13339737,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 27.0,
#                     "Uic": 13339739,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 26.0,
#                     "Uic": 13339740,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 40.0,
#                     "Uic": 13339741,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 35.0,
#                     "Uic": 13339742,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 30.0,
#                     "Uic": 13342453,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 30.0,
#                     "Uic": 13342455,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Call",
#                     "StrikePrice": 32.0,
#                     "Uic": 13342456,
#                     "UnderlyingUic": 16350
#                 },
#                 {
#                     "PutCall": "Put",
#                     "StrikePrice": 32.0,
#                     "Uic": 13342461,
#                     "UnderlyingUic": 16350
#                 }
#             ],
#             "TickSizeScheme": {
#                 "DefaultTickSize": 0.05,
#                 "Elements": [
#                     {
#                         "HighPrice": 5.0,
#                         "TickSize": 0.01
#                     }
#                 ]
#             }
#         }
#     ],
#     "OrderDistances": {
#         "EntryDefaultDistance": 0.0,
#         "EntryDefaultDistanceType": "Percentage",
#         "StopLimitDefaultDistance": 5.0,
#         "StopLimitDefaultDistanceType": "Pips",
#         "StopLossDefaultDistance": 0.5,
#         "StopLossDefaultDistanceType": "Percentage",
#         "StopLossDefaultEnabled": false,
#         "StopLossDefaultOrderType": "Stop",
#         "TakeProfitDefaultDistance": 0.5,
#         "TakeProfitDefaultDistanceType": "Percentage",
#         "TakeProfitDefaultEnabled": false
#     },
#     "PriceToContractFactor": 100.0,
#     "RelatedInstruments": [
#         {
#             "AssetType": "CfdOnStock",
#             "Uic": 16350
#         },
#         {
#             "AssetType": "Stock",
#             "Uic": 16350
#         }
#     ],
#     "RelatedOptionRoots": [],
#     "SettlementStyle": "PhysicalDelivery",
#     "StandardAmounts": [
#         1.0,
#         5.0,
#         10.0,
#         25.0,
#         50.0,
#         100.0,
#         500.0,
#         1000.0
#     ],
#     "SupportedOrderTypes": [
#         "Limit"
#     ],
#     "Symbol": "RDSA:xams",
#     "TickSize": 0.01,
#     "TradableOn": [
#         "9300675"
#     ],
#     "UnderlyingAssetType": "Stock"
# }
